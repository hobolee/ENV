# %%
import folium

# %%
# !pip install cartopy
import cartopy.crs as ccrs
import matplotlib.pyplot as plt

# %%
ax = plt.axes(projection=ccrs.Mollweide())
ax.stock_img()
plt.show()

# %%
m = folium.Map(location=[22.4, 114.3], tiles='Stamen Terrain', attr='Mapbox attribution')
